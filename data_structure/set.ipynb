# %% [markdown]
# # Sets

# %%
set_a=set()
type(set_a)
# Out:
# set

# %%
set_1={10,2,3,5,7,1,6,8,6,9}
set_1
# Out:
# {1, 2, 3, 5, 6, 7, 8, 9, 10}

# %%
set_2={'c','z','d','a','t'}
set_2
# Out:
# {'a', 'c', 'd', 't', 'z'}

# %%
# sorts in ascending order but if there is values as 10 and 2, it will print 10 first as it looks ai first digit
# when there is presence of string
value={1,2,6,10}
print(value)
# Out:
# {1, 2, 10, 6}

# %%
value_1={1,2,3,7,3,5,10,"q"}
print(value_1)
# Out:
# {1, 2, 3, 'q', 5, 7, 10}

# %%
# To add values
# - .add (can add only one value)
# - .update (can add multiple values passed as list)

# %%
value_1.add('Apple')
value_1.update(['a','b','c'])
value_1
# Out:
# {1, 10, 2, 3, 5, 7, 'Apple', 'a', 'b', 'c', 'q'}

# %%
'''
1. remove(value) : throws error if the value is not present in the set
2. discard(value) : doesn't throw error
3. pop(value)
'''

# %%
mix_val = {'c','w','p','a',2,5,8,4,3,2,10,34}
mix_val
# Out:
# {10, 2, 3, 34, 4, 5, 8, 'a', 'c', 'p', 'w'}

# %%
mix_val.discard('y')
mix_val
# Out:
# {10, 2, 3, 34, 4, 5, 8, 'a', 'c', 'p', 'w'}

# %%
mix_val.remove(10)
mix_val
# Out:
# {2, 3, 34, 4, 5, 8, 'a', 'c', 'p', 'w'}

# %%
mix_val.pop()
# Out:
# 2

# %%
# -union
# -intersection
# -difference

# %%
set_1={1,2,3,4}
set_2={1,2,5,6}

# %%
set_1.union(set_2)
# Out:
# {1, 2, 3, 4, 5, 6}

# %%
set_1.intersection(set_2)
# Out:
# {1, 2}

# %%
data={('a','b'),('c','d')}
data_2={('a','b')}
data.union(data_2)
# Out:
# {('a', 'b'), ('c', 'd')}
