# %% [markdown]
# # String Function

# %%
# string function
# Capitalize
# lower, upper
# strip -> to remove white space (both sides)
  #lstrip for left side only and rstrip for right side only.

# isupper
# islower
# isdigit
# special_characters='!@#$%^&*(){}[]><~' 
# this is called regular expression / regex

# %%
username='abc@gmail.com'
password="abcd"
uname = input("Enter username: ").strip()
pwd=input("Enter password: ")
if uname!=username and pwd!=password:
    print("Invalid username or password")
else:
    if uname==username:
        if pwd==password:
            print("Login successful")
        else:
            print("Incorrect password")
    else:
        print("User not found")
# Out:
# Enter username:  abc@gmail.com
# Enter password:  abcd
# Login successful

# %%
text='   abcdefg    '
print(text)
text=text.strip()
print(text.capitalize())
print(text.upper())
# Out:
#    abcdefg
# Abcdefg
# ABCDEFG
